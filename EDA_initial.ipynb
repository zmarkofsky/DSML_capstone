# %% [markdown]
# <a href="https://colab.research.google.com/github/zmarkofsky/DSML_capstone/blob/main/EDA_initial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Fire Data

# %%
df_fire = pd.read_csv("/content/drive/MyDrive/Capstone - Data Science/Fire Data/donneesouvertes-interventions-sim.csv")
df_casernes = pd.read_csv("/content/drive/MyDrive/Capstone - Data Science/Fire Data/casernes.csv")

# %%
df_fire
# Out:
#         INCIDENT_NBR   CREATION_DATE_TIME  ...  LONGITUDE   LATITUDE
# 0              14219  2015-02-07T16:31:16  ... -73.689547  45.543225
# 1              14317  2015-02-07T22:19:06  ... -73.613142  45.540682
# 2              15188  2015-02-10T09:06:01  ... -73.587945  45.518350
# 3              15237  2015-02-10T11:06:18  ... -73.567090  45.461899
# 4              15242  2015-02-10T11:21:30  ... -73.582907  45.583522
# ...              ...                  ...  ...        ...        ...
# 789848         79138  2018-08-10T18:52:29  ... -73.554818  45.519931
# 789849         64734  2017-06-30T18:26:08  ... -73.615169  45.537523
# 789850         50205  2021-06-24T18:55:15  ... -73.542945  45.504659
# 789851         72626  2017-07-21T11:33:40  ... -73.934730  45.455409
# 789852          4920  2020-01-16T12:05:25  ... -73.642505  45.432339
#
# [789853 rows x 13 columns]
# ...

# %%
df_casernes
# Out:
#     CASERNE  NO_CIVIQUE  ...    MTM8_X     MTM8_Y
# 0         3         256  ...  300097.0  5039283.0
# 1        15        1255  ...  300038.0  5038279.0
# 2        23         523  ...  298134.6  5037547.3
# 3        33        6040  ...  297335.0  5035328.0
# 4         9        8100  ...  296200.0  5047099.0
# ..      ...         ...  ...       ...        ...
# 63        8       11371  ...  305092.0  5054628.0
# 64       77         114  ...  293220.0  5034876.0
# 65       55         401  ...  280058.0  5034258.0
# 66       51         550  ...  269580.0  5030970.0
# 67       76          19  ...  297106.0  5038493.0
#
# [68 rows x 11 columns]

# %%
df_fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789853 entries, 0 to 789852
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   INCIDENT_NBR        789853 non-null  int64
#  1   CREATION_DATE_TIME  789853 non-null  object
#  2   INCIDENT_TYPE_DESC  789853 non-null  object
#  3   DESCRIPTION_GROUPE  789828 non-null  object
#  4   CASERNE             789853 non-null  int64
#  5   NOM_VILLE           789853 non-null  object
#  6   NOM_ARROND          789853 non-null  object
#  7   DIVISION            789853 non-null  int64
#  8   NOMBRE_UNITES       789619 non-null  float64
#  9   MTM8_X              789853 non-null  float64
#  10  MTM8_Y              789853 non-null  float64
#  11  LONGITUDE           789853 non-null  float64
#  12  LATITUDE            789853 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 78.3+ MB

# %%
for col_name, col_data in df_fire.iteritems():
     print(col_name)
     print(col_data.unique())
# Out:
# INCIDENT_NBR
# [ 14219  14317  15188 ... 128499 130062 128795]
# CREATION_DATE_TIME
# ['2015-02-07T16:31:16' '2015-02-07T22:19:06' '2015-02-10T09:06:01' ...
#  '2021-06-24T18:55:15' '2017-07-21T11:33:40' '2020-01-16T12:05:25']
# INCIDENT_TYPE_DESC
# ['Premier répondant' 'Appel de Cie de détection' 'Odeur suspecte - gaz'
#  '10-22 sans feu' 'Feu / 4e Alerte' 'Aliments surchauffés'
#  'Alarme privé ou locale' 'Avertisseur de CO' 'Problèmes électriques'
#  'Ac.véh./1R/s.v./ext/29B/D' 'Alarme vérification' 'Ascenseur'
#  'Feu / Agravation possible' 'Ac.véh./1R/s.v./V.R./29B/D' '10-22 avec feu'
#  'Fuite gaz naturel 10-22' 'Inondation' 'Acc. sans victime sfeu - ext.'
#  'Aide à un citoyen' 'Feu de champ *' 'Feu de bâtiment'
#  'Feu de véhicule extérieur' 'Déchets en feu' 'Structure dangereuse'
#  'Avertisseur - gaz F7/GAZ' 'Sauv. naut.\\surfaces glacées'
#  'Matières dangereuses / 10-22' 'Fuite gaz nat 10-07 F7/2GAZ'
#  'Acc. sans victime sfeu - v.r' 'Fuite ext.:hydrocar. liq. div.'
# ...

# %%
for col_name, col_data in df_casernes.iteritems():
     print(col_name)
     print(col_data.unique())
# Out:
# CASERNE
# [ 3 15 23 33  9 37 41 14 38 44 32  4 27 34 46 17 18 16 26 30 21 22 28 29
#  31 47 50  2  5 10 19 20 25 13 39 40 45 48 75 64 71 72 73 57 58 59 35 42
#  43 49 66 67 65 56 52 53 78 61 62 63 79 54 74  8 77 55 51 76]
# NO_CIVIQUE
# [  256  1255   523  6040  8100   795  7405  8216 14201 12145 16101  5260
#   5353  5369  4760  4240 12012  1041  2151     5  6025  5455  7650  5375
#   7041  2111  6490    10    75  1445  2000   920  1212  3250  2915  8639
#   5100  3616    40  3175  5500  2727   820 13795    13 18661 10827  4180
#   1945  4398   911  1300   230   330   310  6815   150   530  5520  3048
#  11371   114   401   550    19]
# RUE
# ['rue  Young' 'rue de la Sucrerie' 'place Saint-Henri' 'boulevard Monk'
#  'boulevard Saint-Michel' 'rue Jarry Est' 'avenue Champagneur'
#  'boulevard Maurice-Duplessis' 'rue Sherbrooke Est'
#  'boulevard Rivière-des-Prairies' 'rue Van Horne' 'rue Gatineau'
#  'chemin de la Côte-Saint-Antoine' 'avenue Cumberland' 'rue de Charleroi'
# ...
